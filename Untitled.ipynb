# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
import findspark
findspark.init()
findspark.find()
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('bankk').getOrCreate()
# Load the data into a PySpark DataFrame
data = spark.read.format("csv").option("header", "true").load("ML_hw_dataset.csv")

# Preprocess the data
indexers = [StringIndexer(inputCol=column, outputCol=column+"_index") for column in ["job", "marital", "education", "default", "housing", "loan", "contact", "month", "day_of_week", "poutcome"]]
encoder = OneHotEncoder(inputCols=[indexer.getOutputCol() for indexer in indexers], outputCols=["{0}_encoded".format(indexer.getOutputCol()) for indexer in indexers])
assembler = VectorAssembler(inputCols=encoder.getOutputCols() + ["age", "duration", "campaign", "pdays", "previous", "emp_var_rate", "cons_price_idx", "cons_conf_idx", "euribor3m", "nr_employed"], outputCol="features")
preprocessed_data = assembler.transform(encoder.transform(indexers[-1].fit(data).transform(data)))

# Split the data into training and test sets
(training_data, test_data) = preprocessed_data.randomSplit([0.8, 0.2])

# Train the logistic regression model
lr = LogisticRegression(labelCol="y", featuresCol="features", maxIter=10, regParam=0.3, elasticNetParam=0.8)
lr_model = lr.fit(training_data)

# Make predictions on the test set
predictions = lr_model.transform(test_data)

# Evaluate the model
evaluator = BinaryClassificationEvaluator(labelCol="y")
area_under_roc = evaluator.evaluate(predictions)

print("Area Under ROC: {0}".format(area_under_roc))
# Out:
# 23/04/09 22:35:20 WARN Utils: Your hostname, hb resolves to a loopback address: 127.0.1.1; using 192.168.1.6 instead (on interface wlp3s0)
# 23/04/09 22:35:20 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/09 22:35:22 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/04/09 22:35:23 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 16
#      14 encoder = OneHotEncoder(inputCols=[indexer.getOutputCol() for indexer in indexers], outputCols=["{0}_encoded".format(indexer.getOutputCol()) for indexer in indexers])
# ...

# %%
# !pip install seaborn

import seaborn as sns
from pyspark.sql.functions import col

# Assuming the Spark DataFrame is already loaded and preprocessed

# Select the categorical column
cat_col = 'job'

# Convert the column to a pandas DataFrame for plotting
data = df.select(col(cat_col)).toPandas()

# Plot the count plot
sns.countplot(x=cat_col, data=data)
plt.xlabel(cat_col)
plt.ylabel('Count')
plt.title('Distribution of ' + cat_col)
plt.show()

# %%
df = spark.read.csv("ML_hw_dataset.csv", inferSchema=True, header=True)

# %%
import matplotlib.pyplot as plt
cat_col = 'age'

# Convert the column to a pandas DataFrame for plotting
data = df.select(col(cat_col)).toPandas()

plt.figure(figsize=(15,8))

# Plot the count plot
sns.countplot(x=cat_col, data=data)
plt.xlabel(cat_col)
plt.ylabel('Count')
plt.title('Distribution of ' + cat_col)
plt.show()

# %%
# !pip install missingno
import missingno as msno
import matplotlib.pyplot as plt
import pyspark.sql.functions as F

# Check missing values in the DataFrame
missing_df = df.select([F.count(F.when(F.col(c).isNull(), c)).alias(c) for c in df.columns])
missing = missing_df.toPandas().transpose()
missing.columns = ['count']
missing['percentage'] = (missing['count']/df.count())*1000

# Create the missing value heatmap using missingno
msno.matrix(df.toPandas())
plt.show()
# Out:
# ...
#   Using cached scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
# ...

# %%
from pyspark.sql.functions import col

# Replace 'unknown' values with null
df = df.na.replace('unknown', None)

# Check missing values in the DataFrame
missing_df = df.select([F.count(F.when(F.col(c).isNull(), c)).alias(c) for c in df.columns])
missing = missing_df.toPandas().transpose()
missing.columns = ['count']
missing['percentage'] = (missing['count']/df.count())*100

# Create the missing value heatmap using missingno
msno.matrix(df.toPandas())
plt.show()

# %%
from pyspark.ml.feature import Imputer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import StandardScaler
from pyspark.ml.feature import PCA
from pyspark.ml.feature import KNNImputer

# Load data into a PySpark DataFrame
df = spark.read.format("csv").option("header", "true").load("ML_hw_dataset.csv")

# Replace 'unknown' with null values
df = df.replace('unknown', None)

# Impute missing values using KNN
cat_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
num_cols = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
imputer = KNNImputer(inputCols=cat_cols+num_cols, outputCols=cat_cols+num_cols)
df_imputed = imputer.fit(df).transform(df)

# Drop rows with null values
df_imputed = df_imputed.dropna()

# Convert categorical columns to numerical using StringIndexer
indexers = [StringIndexer(inputCol=col, outputCol=col+"_index", handleInvalid='keep') for col in cat_cols]
pipeline = Pipeline(stages=indexers)
df_indexed = pipeline.fit(df_imputed).transform(df_imputed)

# Scale numerical columns
assembler = VectorAssembler(inputCols=[col+"_index" if col in cat_cols else col for col in df_indexed.columns], outputCol="features")
df_assembled = assembler.transform(df_indexed)
scaler = StandardScaler(inputCol="features", outputCol="scaled_features")
scaler_model = scaler.fit(df_assembled)
df_scaled = scaler_model.transform(df_assembled)

# Perform PCA for dimensionality reduction
pca = PCA(k=2, inputCol="scaled_features", outputCol="pca_features")
pca_model = pca.fit(df_scaled)
df_pca = pca_model.transform(df_scaled)

# Plot the PCA features
pca_features = df_pca.select("pca_features").rdd.flatMap(lambda x: x).collect()
plt.scatter([x[0] for x in pca_features], [x[1] for x in pca_features])
plt.xlabel("PCA Feature 1")
plt.ylabel("PCA Feature 2")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 6
#       4 from pyspark.ml.feature import StandardScaler
#       5 from pyspark.ml.feature import PCA
# ----> 6 from pyspark.ml.feature import KNNImputer
#       8 # Load data into a PySpark DataFrame
#       9 df = spark.read.format("csv").option("header", "true").load("ML_hw_dataset.csv")
#
# ImportError: cannot import name 'KNNImputer' from 'pyspark.ml.feature' (/media/hb/Multimedia/ui/semester 2/big data/HW5/pyspark-logic-regression/.venv/lib/python3.10/site-packages/pyspark/ml/feature.py)

# %%
from pyspark.sql.functions import col, when
from pyspark.ml.feature import Imputer

# Load data into a PySpark DataFrame
df = spark.read.format("csv").option("header", "true").load("ML_hw_dataset.csv")


# Replace 'unknown' with null values in the DataFrame
df = df.replace('unknown', None)

# Impute missing categorical values with mode
cat_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
imputer_cat = Imputer(inputCols=cat_cols, outputCols=[f"{col}_imputed" for col in cat_cols]).setStrategy("mode")
df = imputer_cat.fit(df).transform(df)

# Impute missing numerical values with mean
num_cols = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
imputer_num = Imputer(inputCols=num_cols, outputCols=[f"{col}_imputed" for col in num_cols]).setStrategy("mean")
df = imputer_num.fit(df).transform(df)

# Drop the original columns with missing values
df = df.drop(*cat_cols).drop(*num_cols)

# Rename the imputed columns to the original column names
for col in cat_cols + num_cols:
    df = df.withColumnRenamed(f"{col}_imputed", col)

# Convert target variable to binary 0/1
df = df.withColumn("y", when(col("y") == "yes", 1).otherwise(0))
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[21], line 14
#      12 cat_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
#      13 imputer_cat = Imputer(inputCols=cat_cols, outputCols=[f"{col}_imputed" for col in cat_cols]).setStrategy("mode")
# ---> 14 df = imputer_cat.fit(df).transform(df)
#      16 # Impute missing numerical values with mean
#      17 num_cols = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
#
# File /media/hb/Multimedia/ui/semester 2/big data/HW5/pyspark-logic-regression/.venv/lib/python3.10/site-packages/pyspark/ml/base.py:205, in Estimator.fit(self, dataset, params)
#     203         return self.copy(params)._fit(dataset)
#     204     else:
# --> 205         return self._fit(dataset)
# ...

# %%
from pyspark.sql.functions import col, when
from pyspark.ml.feature import Imputer

# Load data into a PySpark DataFrame
df = spark.read.format("csv").option("header", "true").load("ML_hw_dataset.csv")

# Replace 'unknown' with null values in the DataFrame
df = df.replace('unknown', None)

# Impute missing categorical values with mode
cat_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
imputer_cat = Imputer(inputCols=cat_cols, outputCols=[f"{col}_imputed" for col in cat_cols]).setStrategy("mode")
df = imputer_cat.fit(df).transform(df)

# Impute missing numerical values with mean
num_cols = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
imputer_num = Imputer(inputCols=num_cols, outputCols=[f"{col}_imputed" for col in num_cols]).setStrategy("mean")
df = imputer_num.fit(df).transform(df)

# Drop the original columns with missing values
df = df.drop(*cat_cols).drop(*num_cols)

# Rename the imputed columns to the original column names
for col in cat_cols + num_cols:
    df = df.withColumnRenamed(f"{col}_imputed", col)

# Convert target variable to binary 0/1
df = df.withColumn("y", when(col("y") == "yes", 1).otherwise(0))
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[22], line 13
#      11 cat_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
#      12 imputer_cat = Imputer(inputCols=cat_cols, outputCols=[f"{col}_imputed" for col in cat_cols]).setStrategy("mode")
# ---> 13 df = imputer_cat.fit(df).transform(df)
#      15 # Impute missing numerical values with mean
#      16 num_cols = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
#
# File /media/hb/Multimedia/ui/semester 2/big data/HW5/pyspark-logic-regression/.venv/lib/python3.10/site-packages/pyspark/ml/base.py:205, in Estimator.fit(self, dataset, params)
#     203         return self.copy(params)._fit(dataset)
#     204     else:
# --> 205         return self._fit(dataset)
# ...

# %%
from pyspark.ml.feature import Imputer, StringIndexer, IndexToString
from pyspark.ml import Pipeline

# Load data into a PySpark DataFrame
df = spark.read.format("csv").option("header", "true").load("ML_hw_dataset.csv")

# Replace 'unknown' with null values in the DataFrame
df = df.replace('unknown', None)

# Convert categorical columns to numeric columns using StringIndexer
cat_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
indexers = [StringIndexer(inputCol=col, outputCol=f"{col}_indexed").setHandleInvalid("skip") for col in cat_cols]
pipeline = Pipeline(stages=indexers)
df = pipeline.fit(df).transform(df)

# Impute missing values for the newly numeric columns
num_cols = [f"{col}_indexed" for col in cat_cols] + ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
imputer = Imputer(inputCols=num_cols, outputCols=[f"{col}_imputed" for col in num_cols]).setStrategy("mean")
df = imputer.fit(df).transform(df)

# Convert the numeric columns back to categorical columns using IndexToString
converters = [IndexToString(inputCol=f"{col}_imputed", outputCol=col) for col in cat_cols]
pipeline = Pipeline(stages=converters)
df = pipeline.fit(df).transform(df)

# Drop the original columns with missing values
df = df.drop(*cat_cols).drop(*num_cols)

# Convert target variable to binary 0/1
df = df.withColumn("y", when(col("y") == "yes", 1).otherwise(0))
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[24], line 19
#      17 num_cols = [f"{col}_indexed" for col in cat_cols] + ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']
#      18 imputer = Imputer(inputCols=num_cols, outputCols=[f"{col}_imputed" for col in num_cols]).setStrategy("mean")
# ---> 19 df = imputer.fit(df).transform(df)
#      21 # Convert the numeric columns back to categorical columns using IndexToString
#      22 converters = [IndexToString(inputCol=f"{col}_imputed", outputCol=col) for col in cat_cols]
#
# File /media/hb/Multimedia/ui/semester 2/big data/HW5/pyspark-logic-regression/.venv/lib/python3.10/site-packages/pyspark/ml/base.py:205, in Estimator.fit(self, dataset, params)
#     203         return self.copy(params)._fit(dataset)
#     204     else:
# ...

# %%
from pyspark.sql.functions import *

df.select(histogram("age", bins=10, range=(0, 100)).alias("age_hist")).show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 from pyspark.sql.functions import *
# ----> 3 df.select(histogram("age", bins=10, range=(0, 100)).alias("age_hist")).show(truncate=False)
#
# NameError: name 'histogram' is not defined

# %%
import pyspark
print(pyspark.__version__)
# Out:
# 3.3.2

# %%
from pyspark.sql.functions import histogram_numeric

df.select(histogram_numeric("age", 10, 0, 100).alias("age_hist")).show(truncate=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from pyspark.sql.functions import histogram_numeric
#       3 df.select(histogram_numeric("age", 10, 0, 100).alias("age_hist")).show(truncate=False)
#
# ImportError: cannot import name 'histogram_numeric' from 'pyspark.sql.functions' (/media/hb/Multimedia/ui/semester 2/big data/HW5/pyspark-logic-regression/.venv/lib/python3.10/site-packages/pyspark/sql/functions.py)

# %%
df.approxQuantile("age", [0.25, 0.5, 0.75], 0.01)
# Out:
# [Stage 102:>                                                        (0 + 2) / 2]
# [32.0, 38.0, 47.0]

# %%
# !pip install pyspark_dist_explore

# %%
from pyspark.sql.functions import col
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml import Pipeline

# Load the data into a DataFrame
df = spark.read.csv("ML_hw_dataset.csv", inferSchema=True, header=True)

# Convert any string categorical columns to numerical
indexers = [StringIndexer(inputCol=col, outputCol=col+"_index", handleInvalid='skip') for col in ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']]
pipeline1 = Pipeline(stages=indexers)
df = pipeline1.fit(df).transform(df)

# One-hot encode the indexed categorical columns
encoders = [OneHotEncoder(inputCol=col+"_index", outputCol=col+"_vec") for col in ['marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']]
pipeline2 = Pipeline(stages=encoders)
df = pipeline2.fit(df).transform(df)

# Assemble all the features into a single vector
assembler = VectorAssembler(inputCols=['age', 'job_index', 'marital_vec', 'education_vec', 'default_vec', 'housing_vec', 'loan_vec', 'contact_vec', 'month_vec', 'day_of_week_vec', 'duration', 'campaign', 'pdays', 'previous', 'poutcome_vec', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed'], outputCol='features')
df = assembler.transform(df)

# Split the data into training and testing sets
(trainingData, testData) = df.randomSplit([0.7, 0.3], seed=42)

# Fit a logistic regression model on the training data
lr = LogisticRegression(labelCol='y', featuresCol='features', maxIter=10)
model = lr.fit(trainingData)

# Evaluate the model on the testing data
predictions = model.transform(testData)
evaluator = BinaryClassificationEvaluator(labelCol='y', rawPredictionCol='prediction')
auc = evaluator.evaluate(predictions)

print("Area Under ROC Curve = %g" % auc)
# Out:
# [Stage 346:============================>                            (1 + 1) / 2]
# Area Under ROC Curve = 0.697508

# %%
from pyspark.ml.classification import LogisticRegression, RandomForestClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
import matplotlib.pyplot as plt

# Split the preprocessed dataset into training and testing sets
train, test = df.randomSplit([0.7, 0.3])

# Train a logistic regression model
lr = LogisticRegression(featuresCol='features', labelCol='y')
lr_model = lr.fit(train)

# Evaluate the logistic regression model on the testing set
lr_predictions = lr_model.transform(test)
lr_evaluator = BinaryClassificationEvaluator(labelCol='y', metricName='areaUnderROC')
lr_auc = lr_evaluator.evaluate(lr_predictions)

# Train a random forest classifier
rf = RandomForestClassifier(featuresCol='features', labelCol='y')
rf_model = rf.fit(train)

# Evaluate the random forest classifier on the testing set
rf_predictions = rf_model.transform(test)
rf_evaluator = BinaryClassificationEvaluator(labelCol='y', metricName='areaUnderROC')
rf_auc = rf_evaluator.evaluate(rf_predictions)

# Create a side-by-side bar plot of the AUC scores of the two models
models = ['Logistic Regression', 'Random Forest']
auc_scores = [lr_auc, rf_auc]
plt.bar(models, auc_scores)
plt.xlabel('Model')
plt.ylabel('Area Under ROC Curve (AUC)')
plt.title('Comparison of Model Performance')
plt.show()

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import OneHotEncoder, StringIndexer
from pyspark.ml import Pipeline

# Create a SparkSession
spark = SparkSession.builder.appName("OneHotEncoderExample").getOrCreate()

# Read the data
df = spark.read.format("csv").option("header", "true").load("ML_hw_dataset.csv")

# Define categorical columns
cat_cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']

# StringIndexer to convert string categorical columns to numerical
indexers = [StringIndexer(inputCol=col, outputCol=col+"_normalized", handleInvalid='skip') for col in cat_cols]

# OneHotEncoder to convert indexed categorical columns to binary
encoders = [OneHotEncoder(inputCol=col+"_normalized", outputCol=col+"_vec") for col in cat_cols]

# Pipeline to chain multiple transformation stages together
pipeline = Pipeline(stages=indexers + encoders)

# Fit and transform the pipeline on the input dataframe
df_transformed = pipeline.fit(df).transform(df)

# Show the transformed dataframe
df_transformed.toPandas()

# Stop the SparkSession
spark.stop()
# Out:
# 23/04/10 02:03:47 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
